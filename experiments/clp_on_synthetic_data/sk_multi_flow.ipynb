# %%
# %matplotlib notebook
from skmultiflow.data import RandomRBFGenerator
from skmultiflow.bayes import NaiveBayes
from skmultiflow.prototype import RobustSoftLearningVectorQuantization
from skmultiflow.evaluation import EvaluatePrequential

# %%
# 1. Create a stream
stream = RandomRBFGenerator(n_classes=10, n_features=10, n_centroids=10)
# 2. Instantiate the classifier
nb = NaiveBayes()
lvq = RobustSoftLearningVectorQuantization(prototypes_per_class=1,  sigma=2.5)
# 3. Setup the evaluator
evaluator = EvaluatePrequential(show_plot=True,
                                pretrain_size=100,
                                n_wait = 100,
                                max_samples=2000,
                                metrics=['accuracy'])
# 4. Run evaluation
evaluator.evaluate(stream=stream, model=[nb,lvq])
# Out:
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  #################### [100%] [2.90s]
# Processed samples: 2000
# Mean performance:
# M0 - Accuracy     : 0.9495
# M1 - Accuracy     : 0.8742
# [NaiveBayes(nominal_attributes=None),
#  RobustSoftLearningVectorQuantization(gamma=0.9, gradient_descent='vanilla',
#                                       initial_prototypes=None,
#                                       prototypes_per_class=1, random_state=None,
#                                       sigma=2.5)]
