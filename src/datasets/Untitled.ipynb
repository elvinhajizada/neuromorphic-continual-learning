# %%
import glob
from tqdm import tqdm
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import os
import importlib

from sklearn.model_selection import train_test_split

import torchvision.transforms as transforms
from torch.utils.data import Dataset
from torchvision.utils import make_grid
import torch
from avalanche.benchmarks.datasets.downloadable_dataset import SimpleDownloadableDataset
import datasets
from datasets.wrgbd import WRGBD

# %%
importlib.reload(datasets.wrgbd)
from datasets.wrgbd import WRGBD

dataset_dir = '/home/ehajizad/datasets/rgbd-dataset'
dataset = WRGBD(root_dir = dataset_dir)
# Out:
# 7 bject are loaded
# 10 bject are loaded
# 16 bject are loaded
# 24 bject are loaded
# 30 bject are loaded
# 35 bject are loaded
# 41 bject are loaded
# 46 bject are loaded
# 52 bject are loaded
# 57 bject are loaded
# 71 bject are loaded
# 75 bject are loaded
# 87 bject are loaded
# 96 bject are loaded
# 102 bject are loaded
# 110 bject are loaded
# 118 bject are loaded
# 122 bject are loaded
# 131 bject are loaded
# 135 bject are loaded
# 139 bject are loaded
# 142 bject are loaded
# 146 bject are loaded
# 151 bject are loaded
# 156 bject are loaded
# 161 bject are loaded
# 167 bject are loaded
# 171 bject are loaded
# 174 bject are loaded
# 178 bject are loaded
# 185 bject are loaded
# 190 bject are loaded
# 198 bject are loaded
# 202 bject are loaded
# 208 bject are loaded
# 211 bject are loaded
# 217 bject are loaded
# 229 bject are loaded
# 235 bject are loaded
# 241 bject are loaded
# 246 bject are loaded
# 253 bject are loaded
# 257 bject are loaded
# 263 bject are loaded
# ...

# %%
plt.imshow(dataset[0][0])

# %%
img = Image.open('/home/ehajizad/datasets/rgbd-dataset/binder/binder_1/binder_1_1_2_crop.png')
plt.imshow(img)
binder_1_1_41_loc.txt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [144], in <cell line: 3>()
#       1 img = Image.open('/home/ehajizad/datasets/rgbd-dataset/binder/binder_1/binder_1_1_2_crop.png')
#       2 plt.imshow(img)
# ----> 3 binder_1_1_41_loc.txt
#
# NameError: name 'binder_1_1_41_loc' is not defined

# %%
with open('/home/ehajizad/datasets/rgbd-dataset/binder/binder_1/binder_1_1_41_loc.txt') as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['198,194\n']
